# %% [markdown]
# # Parte 2 - Completar dataset de accidentes de aviones mediante scrapping

# %%
import pandas as pd

# %%
data = pd.read_csv("Airplane_Crashes_and_Fatalities_Since_1908.csv.zip", compression = 'zip')
print 'Numero de filas:',len(data)
data.head()
# Out:
# Numero de filas: 5268
#          Date   Time                            Location  \
# 0  09/17/1908  17:18                 Fort Myer, Virginia
# 1  07/12/1912  06:30             AtlantiCity, New Jersey
# 2  08/06/1913    NaN  Victoria, British Columbia, Canada
# 3  09/09/1913  18:30                  Over the North Sea
# 4  10/17/1913  10:30          Near Johannisthal, Germany
#
#                  Operator Flight #          Route                    Type  \
# 0    Military - U.S. Army      NaN  Demonstration        Wright Flyer III
# 1    Military - U.S. Navy      NaN    Test flight               Dirigible
# 2                 Private        -            NaN        Curtiss seaplane
# 3  Military - German Navy      NaN            NaN  Zeppelin L-1 (airship)
# 4  Military - German Navy      NaN            NaN  Zeppelin L-2 (airship)
#
#   Registration cn/In  Aboard  Fatalities  Ground  \
# 0          NaN     1     2.0         1.0     0.0
# 1          NaN   NaN     5.0         5.0     0.0
# 2          NaN   NaN     1.0         1.0     0.0
# 3          NaN   NaN    20.0        14.0     0.0
# 4          NaN   NaN    30.0        30.0     0.0
#
#                                              Summary
# 0  During a demonstration flight, a U.S. Army fly...
# 1  First U.S. dirigible Akron exploded just offsh...
# 2  The first fatal airplane accident in Canada oc...
# 3  The airship flew into a thunderstorm and encou...
# 4  Hydrogen gas which was being vented was sucked...

# %% [markdown]
# Vamos a intentar añadir una nueva columna al dataframe, denominada 'Role', que indique el cometido para el que el tipo de avión está destinado ('bombardero', 'trasporte militar', 'transporte de pasajeros', ...)

# %% [markdown]
# Vamos a tomar como ejemplo el enlace del enunciado de la prueba:
# 'https://en.wikipedia.org/wiki/Breguet_14'
# En la tabla de la derecha, aparece una tabla con información acerca del avión, como su cometido, su fabricante, las aerolíneas que lo han usado, etc. En concreto, para el Breguet 14, su cometido fue el de bombardero. La idea es extraer esta información mediante scrapping.

# %% [markdown]
# En Chrome, podemos acceder al código de la página, pichando con el botón derecho del ratón sobre la página y seleccionando inspeccionar. Usando la biblioteca BeautifulSoup, podemos acceder al contenido de la tabla y extraer la información que necesitamos de manera rápida.

# %%
from bs4 import BeautifulSoup
from urllib2 import urlopen

url = "https://en.wikipedia.org/wiki/Breguet_14"
soup = BeautifulSoup(urlopen(url).read(), "lxml")
table = soup.find('table')
table_headers = table.find_all('th')
for h in table_headers:
    if 'Role' in h:
        row = h.find_parent()
str(row.getText()).split('\n')[2]
# Out:
# 'Bomber'

# %% [markdown]
# Ahora tendríamos que repetir este procedimient para cada tipo de avión. Vamos a calcular el número de tipos diferentes de avión que aparecen en el dataset.

# %%
len(data['Type'].unique())
# Out:
# 2447

# %% [markdown]
# Nos encontramos con la problemática de que para cinco mil registros de accidentes aéreos, parece que han sido cometidos por dos mil quinientos tipos de aviones diferentes!! Lo más probable es que los valores de la columna 'Type' no sean consistentes y el mismo tipo de avión aparezca registrado con diferente nomenclatura.

# %% [markdown]
# Por ejemplo, vamos a ver las inconsistencias en nomenclatura para los aviones 'Antonov'

# %%
antonov = data[data['Type'].str.contains('Antonov') == True]['Type'].unique()
print len(antonov)
print antonov
# Out:
# 76
# ['Antonov AN-9' 'Antonov AN-10' 'Antonov AN-10A' 'Antonov An-10A'
#  'Antonov AN-12' 'Antonov AN-24B' 'Antonov AN-24' 'Antonov AN-12BP'
#  'Antonov An-12 - Ilyshin IL-14' 'Antonov AN-24V' 'Antonov An-12PL'
#  'Antonov An-12TB' 'Antonov AN-22' 'Antonov An-12B' 'Antonov An-10'
#  'Antonov AN-26' 'Antonov An-24B' 'Antonov AN-12V' 'Antonov An-24'
#  'Antonov AN-24RV' 'Antonov AN-24 / Yakovlev Yak-40' 'Antonov An-12BP'
#  'Antonov An-12' 'Antonov AN-24N' 'Antonov 2PF'
#  'Antonov AN-24RV / Soviet Air Force TU-16' 'Antonov An-24RV'
#  'Antonov An-2T' 'Antonov An-32' 'Tupolev TU-134A / Antonov An-26'
#  'Antonov An-12AP' 'Antonov An-26' 'Antonov 12BP' 'Antonov AN-32'
#  'Antonov AN-8' 'Antonov AN-72' 'Antonov AN-30' 'Antonov 12BK' 'Antonov 32'
#  'Antonov AN-28' 'Antonov AN-22A' 'Antonov AN-26B' 'Antonov AN-124'
#  'Antonov AN-32B' 'Antonov AN-2' 'Antonov 26B' 'Antonov 2R' 'Antonov An-2R'
#  'Antonov 12B' 'Antonov An-124' 'Antonov AN-12B' 'Antonov An-32B'
#  'Antonov AN-124-100' 'Antonov An-72' 'Antonov 12' 'Antonov 32B'
#  'Antonov AN-32 Transport' 'Antonov 28' 'Antonov AN-12 (freighter)'
#  'Antonov 12MGA' 'Antonov AN-28 PZL-MieleM-28 Sky Truck' 'Antonov 2TP'
#  'Antonov AN-32A' 'Antonov AN-140' 'Antonov 24B' 'Antonov AN-2TP'
#  'Antonov 24' 'Antonov AN-26A' 'Antonov 12V' 'Antonov AN-140-100'
#  'Antonov 74TK-200' 'Antonov An-2' 'Antonov 74T-200' 'Antonov 26B-100'
#  'Antonov AN-26V' 'Antonov An-28']

# %% [markdown]
# Vemos que solo para 'Antonov' aparecen 76 tipos diferentes, debido a las inconsistencias en nomenclatura. Por ejemplo, 'Antonov AN-10' aparece como 'Antonov AN-10', 'Antonov AN-10A' 'Antonov An-10A', 'Antonov An-10', es decir, cuatro referencias distintas para el mismo modelo (o variantes del modelo).

# %% [markdown]
# Intentar dar consistencia a todos los valores de esta columna sería lo ideal, pero es un proceso muy laborioso. Es por ello que vamos a centrarnos en los tipos de avión que se vieron implicados en un mayor número de accidentes.

# %%
mas_accidentados = (data.groupby('Type')['Fatalities'].count()).sort_values(ascending = False)
aviones_mas_accidentados = list(mas_accidentados.index.values[0:30])
aviones_mas_accidentados
# Out:
# ['Douglas DC-3',
#  'de Havilland Canada DHC-6 Twin Otter 300',
#  'Douglas C-47A',
#  'Douglas C-47',
#  'Douglas DC-4',
#  'Yakovlev YAK-40',
#  'Antonov AN-26',
#  'Junkers JU-52/3m',
#  'Douglas C-47B',
#  'Douglas DC-6B',
#  'De Havilland DH-4',
#  'Breguet 14',
#  'Curtiss C-46A',
#  'Douglas C-47-DL',
#  'Douglas DC-6',
#  'McDonnell Douglas DC-9-32',
#  'Antonov AN-24',
#  'Antonov AN-12',
#  'Curtiss C-46',
#  'Embraer 110P1 Bandeirante',
#  'Junkers F-13',
#  'Tupolev TU-134A',
#  'Fokker F-27 Friendship 600',
#  'de Havilland Canada DHC-6 Twin Otter 100',
#  'Cessna 208B Grand Caravan',
#  'Lockheed C-130H',
#  'Fokker F-27 Friendship 200',
#  'de Havilland Canada DHC-6 Twin Otter 200',
#  'Britten-Norman BN-2A Islander',
#  'Lockheed 18 Lodestar']

# %% [markdown]
# De ellos, 'de Havilland Canada DHC-6 Twin Otter 300', 'de Havilland Canada DHC-6 Twin Otter 100' y 'de Havilland Canada DHC-6 Twin Otter 200', son variantes del mismo modelo. Lo mismo sucede con 'Douglas C-47A', 'Douglas C-47' y 'Douglas C-47-DL', los 'Fokker F-27 Friendship' y los 'Curtis C-46'.

# %%
def consistente(x):
    if (x == 'de Havilland Canada DHC-6 Twin Otter 100' or x == 'de Havilland Canada DHC-6 Twin Otter 200' or\
        x == 'de Havilland Canada DHC-6 Twin Otter 300'):
        x = 'de Havilland Canada DHC-6 Twin Otter'
    if (x == 'Douglas C-47A' or x == 'Douglas C-47' or x == 'Douglas C-47-DL'):
        x = 'Douglas C-47'
    if (x == 'Fokker F-27 Friendship 200' or x == 'Fokker F-27 Friendship 600'):
        x = 'Fokker F-27 Fiendship'
    if (x == 'Curtiss C-46' or x == 'Curtiss C-46A'):
        x = 'Curtiss C-46'
    return x

# %%
data['Type'] = data['Type'].map(lambda x: consistente(x))

# %% [markdown]
# Volvemos a calcular y reducimos a 9 tipos de avion.

# %%
mas_accidentados = (data.groupby('Type')['Fatalities'].count()).sort_values(ascending = False)
aviones_mas_accidentados = list(mas_accidentados.index.values[0:8])
aviones_mas_accidentados
# Out:
# ['Douglas DC-3',
#  'Douglas C-47',
#  'de Havilland Canada DHC-6 Twin Otter',
#  'Douglas DC-4',
#  'Curtiss C-46',
#  'Yakovlev YAK-40',
#  'Antonov AN-26',
#  'Fokker F-27 Fiendship']

# %% [markdown]
# Lo siguiente es obtener mediante scrapping el valor 'Role' para cada uno de estos tipos.

# %%
url_list = ['https://en.wikipedia.org/wiki/Douglas_DC-3',
            'https://en.wikipedia.org/wiki/Douglas_C-47_Skytrain',
            'https://en.wikipedia.org/wiki/De_Havilland_Canada_DHC-6_Twin_Otter',
            'https://en.wikipedia.org/wiki/Douglas_DC-4',
            'https://en.wikipedia.org/wiki/Curtiss_C-46_Commando',
            'https://en.wikipedia.org/wiki/Yakovlev_Yak-40',
            'https://en.wikipedia.org/wiki/Antonov_An-26',
            'https://en.wikipedia.org/wiki/Fokker_F27_Friendship']
role_list = []
for url in url_list:
    soup = BeautifulSoup(urlopen(url).read(), "lxml")
    table = soup.find('table')
    headers = table.find_all('th')
    for h in headers:
        if 'Role' in h:
            row = h.find_parent()
    role_list.append(str(row.getText()).split('\n')[2])
role_list
# Out:
# ['Airliner and transport aircraft',
#  'Military transport aircraft',
#  'Utility aircraft',
#  'Airliner/transport aircraft',
#  'Military transport aircraft',
#  'Regional jet/ VIP transport',
#  'Transport aircraft',
#  'Transport aircraft']

# %% [markdown]
# Creamos el dataframe que asocia a cada tipo con su role.

# %%
r = {'Type': aviones_mas_accidentados,
    'Role':role_list}
role_df = pd.DataFrame(r, columns = ['Type', 'Role'])
role_df
# Out:
#                                    Type                             Role
# 0                          Douglas DC-3  Airliner and transport aircraft
# 1                          Douglas C-47      Military transport aircraft
# 2  de Havilland Canada DHC-6 Twin Otter                 Utility aircraft
# 3                          Douglas DC-4      Airliner/transport aircraft
# 4                          Curtiss C-46      Military transport aircraft
# 5                       Yakovlev YAK-40      Regional jet/ VIP transport
# 6                         Antonov AN-26               Transport aircraft
# 7                 Fokker F-27 Fiendship               Transport aircraft

# %% [markdown]
# Añadimos la nueva columna al dataframe existente de los accidentes de avión.

# %%
new_data = data.merge(role_df, how = 'outer')

# %%
print new_data.head()
# Out:
#          Date   Time                            Location  \
# 0  09/17/1908  17:18                 Fort Myer, Virginia
# 1  07/12/1912  06:30             AtlantiCity, New Jersey
# 2  08/06/1913    NaN  Victoria, British Columbia, Canada
# 3  09/09/1913  18:30                  Over the North Sea
# 4  10/17/1913  10:30          Near Johannisthal, Germany
#
#                  Operator Flight #          Route                    Type  \
# 0    Military - U.S. Army      NaN  Demonstration        Wright Flyer III
# 1    Military - U.S. Navy      NaN    Test flight               Dirigible
# 2                 Private        -            NaN        Curtiss seaplane
# 3  Military - German Navy      NaN            NaN  Zeppelin L-1 (airship)
# 4  Military - German Navy      NaN            NaN  Zeppelin L-2 (airship)
#
#   Registration cn/In  Aboard  Fatalities  Ground  \
# 0          NaN     1     2.0         1.0     0.0
# 1          NaN   NaN     5.0         5.0     0.0
# 2          NaN   NaN     1.0         1.0     0.0
# 3          NaN   NaN    20.0        14.0     0.0
# 4          NaN   NaN    30.0        30.0     0.0
#
#                                              Summary Role
# 0  During a demonstration flight, a U.S. Army fly...  NaN
# 1  First U.S. dirigible Akron exploded just offsh...  NaN
# 2  The first fatal airplane accident in Canada oc...  NaN
# 3  The airship flew into a thunderstorm and encou...  NaN
# 4  Hydrogen gas which was being vented was sucked...  NaN

# %% [markdown]
# Vemos que se ha añadido la columna 'Role'. Comprobamos que contiene los valores obtenidos para los tipos de avión elegidos.

# %%
new_data[new_data['Type'].str.contains('de Havilland Canada DHC-6 Twin Otter') == True]
# Out:
#             Date   Time                                      Location  \
# 2652  03/11/1967    NaN                             Mt Visenti, Italy
# 2653  11/23/1968  19:59                         Santa Ana, California
# 2654  07/15/1969  06:57                       New York City, New York
# 2655  02/10/1970  18:37                Long Island Sound, Connecticut
# 2656  04/28/1970    NaN                          Kainatu,  New Guinea
# 2657  05/27/1972    NaN                       Near Helgoland, Germany
# 2658  07/11/1972  16:00                          Near Grytoya, Norway
# 2659  12/21/1972    NaN     Off St. Maarten off, Netherlands Antilles
# 2660  02/28/1973    NaN                        Near Nabire, Indonesia
# 2661  04/18/1973    NaN                          Bamiyan, Afghanistan
# 2662  01/06/1975    NaN               Sierra del Aconquija, Argentina
# 2663  03/18/1975    NaN                                  Singa, Sudan
# 2664  09/30/1975    NaN                          Klua Tan Tan, Canada
# 2665  05/04/1976    NaN                            Near Monze, Zambia
# 2661               Bakhtar Afghan Airlines      NaN
# 2662             Military - Argentine Navy      NaN
# 2663                         Sudan Airways      NaN
# 2664              Northern Thunderbird Air      NaN
# 2665                 de Havilland Aircraft      NaN
# 2666                Air West Airlines Ltd.      NaN
# 2667                  AtlantiCity Airlines      977
# 2668         Northern Thunderbird Air Ltd.      NaN
# 2669            Merpati Nusantara Airlines      NaN
# 2670                                  LADE      NaN
# 2671        Alaska Aeronautical Industries      302
# 2672                         Burma Airways      NaN
# 2673                        Kenn Borek Air      NaN
# 2674                         Burma Airways      NaN
# 2675               Lineas Areas del Centro      NaN
# 2676                        Air Guadeloupe      NaN
# 2677                Rocky Mountain Airways      217
# 2678                       Air New England      248
# 2679                  Bradley Air Services      NaN
# 2680                        West Coast Air      NaN
# 2681   Procurator Generale de la Republica      NaN
# ...                                    ...      ...
# 2741                             First Air       64
# 2742                         Malu Aviation      NaN
# 2743                         ACES Colombia      148
# 2744                   Polynesian Airlines      211
# 2745                   Goroka Air Services      NaN
# 2746                      TMK Air Commuter      NaN
# 2747                       Lumbini Airways      NaN
# 2748                   Cabo Verde Airlines      NaN
# 2749                   Provincial Airlines      960
# 2750                              Aerotaca      NaN
# 2751                                Vanair      NaN
# 2752                       Skyline Airways      NaN
# 2753                            Aeroperlas      NaN
# 2754                      Win Win Aviation      NaN
# 2755                  Royal Nepal Airlines      NaN
# 2756                          Air Caraibes     1501
# 2757                   Trigana Air Service      NaN
# 2758                       Skyline Airways      NaN
# 2759                       PT Air Regional      NaN
# 2760                                GT Air      NaN
# 2761                   Trigana Air Service      NaN
# 2762                          Air São Tomé      NaN
# 2763                         Yeti Airlines      NaN
# 2764           Military - French Air Force      NaN
# 2765         Military - Peruvian Air Force      NaN
# 2766                            Air Moorea     1121
# 2767                       Wiggins Airways      NaN
# 2768                         Yeti Airlines      NaN
# 4046      Aerolineas Centrales de Colombia      NaN
# 4047               Aeroejecutivos Colombia      NaN
#
#                               Route                                      Type  \
# 2652              Venezia - Belluno      de Havilland Canada DHC-6 Twin Otter
# 2653        Los Angeles - Santa Ana      de Havilland Canada DHC-6 Twin Otter
# 2654              New York - Newark      de Havilland Canada DHC-6 Twin Otter
# 2655      Groton, CT - New York, NY      de Havilland Canada DHC-6 Twin Otter
# 2656                            NaN      de Havilland Canada DHC-6 Twin Otter
# 2657                            NaN      de Havilland Canada DHC-6 Twin Otter
# 2658              Bardufoss - Bodoe      de Havilland Canada DHC-6 Twin Otter
# 2659       Guadeloupe - St. Maarten      de Havilland Canada DHC-6 Twin Otter
# 2660                            NaN      de Havilland Canada DHC-6 Twin Otter
# 2661                Bamiyan - Kabul      de Havilland Canada DHC-6 Twin Otter
# 2662                            NaN      de Havilland Canada DHC-6 Twin Otter
# 2663                            NaN      de Havilland Canada DHC-6 Twin Otter
# 2664     Prince George - Dease Lake      de Havilland Canada DHC-6 Twin Otter
# 2665                            NaN      de Havilland Canada DHC-6 Twin Otter
# 2666                            NaN      de Havilland Canada DHC-6 Twin Otter
# 2667          AtlantiCity - Cap May      de Havilland Canada DHC-6 Twin Otter
# 2668  Prince George - Prince Rupert      de Havilland Canada DHC-6 Twin Otter
# 2669               Palu - Toli Toli      de Havilland Canada DHC-6 Twin Otter
# 2670          El Bolson - Rivadavia      de Havilland Canada DHC-6 Twin Otter
# 2671            Iliamna - Anchorage      de Havilland Canada DHC-6 Twin Otter
# 2672           Mongasat - Keng Tung      de Havilland Canada DHC-6 Twin Otter
# 2673                            NaN      de Havilland Canada DHC-6 Twin Otter
# 2674                            NaN      de Havilland Canada DHC-6 Twin Otter
# 
# 2663       ST-ADB    85     6.0         5.0     0.0
# 2664       CF-MHU   142     7.0         7.0     0.0
# 2665       C-GDHA   428    11.0        11.0     0.0
# 2666       C-FAWF    67    19.0         1.0     0.0
# 2667       N101AC   262    10.0         3.0     0.0
# 2668       C-GNTB   463    12.0        12.0     0.0
# 2669       PK-NUP   486    23.0        15.0     0.0
# 2670         T-87   230     6.0         6.0     0.0
# 2671       N563MA   196    13.0        13.0     0.0
# 2672       XY-AEH   540    19.0        19.0     0.0
# 2673       CF-ABW   278     8.0         8.0     0.0
# 2674       XY-AEI   541    14.0        14.0     0.0
# 2675       XA-BOP    18    21.0        18.0     0.0
# 2676       F-OGHD   469    20.0        15.0     0.0
# 2677        N25RM   387    22.0         2.0     0.0
# 2678       N383EX   245    10.0         1.0     0.0
# 2679       C-GROW   415     9.0         9.0     0.0
# 2680       C-FWAF   122    16.0         2.0     0.0
# 2681       XC-BOS   519    10.0        10.0     0.0
# ...           ...   ...     ...         ...     ...
# 2741       C-GNDN   427     2.0         2.0     0.0
# 2742       9Q-CXK    74    21.0         6.0     0.0
# 2743      HK-2602   746    15.0        14.0     0.0
# 2744       5W-FAU   678     5.0         3.0     0.0
# 2745       P2-MMU   250     4.0         2.0     0.0
# 2746       9Q-CBO   735    22.0        22.0     0.0
# 2747       9N-ACC   710    18.0        18.0     0.0
# 2748       D4-CAX   550    22.0         1.0     0.0
# 2749       C-FWLQ   724     2.0         1.0     0.0
# 2750      HK-2760   777     5.0         5.0     0.0
# 2751       YJ-RV9   694    12.0         7.0     0.0
# 2752       9N-AFL   796    10.0        10.0     0.0
# 2753   HP-1267APP   624    10.0        10.0     0.0
# 2754       N201RH   163     3.0         1.0     0.0
# 2755       9N-ABP   654    25.0        25.0     0.0
# 2756       F-OGES   254    19.0        19.0     1.0
# 2757       PK-YPZ   458     6.0         6.0     0.0
# 2758       9N-AGF   828     4.0         4.0     0.0
# 2759       PK-WAY   261    16.0         4.0     0.0
# 2760       PK-LTZ    23    18.0        18.0     0.0
# 2761       PK-YPY   535    12.0        12.0     0.0
# 2762       S9-BAL   648     4.0         4.0     0.0
# 2763       9N-AEQ   708     9.0         9.0     0.0
# 2764       742/CB   742     9.0         9.0     0.0
# 2765      FAP-303   483    20.0        13.0     0.0
# 2766        F-OIQ   608    20.0        20.0     0.0
# 2767       N656WA    47     1.0         1.0     0.0
# 2768      9N-AFE    720    19.0        18.0     0.0
# 4046      HK-2536   713    22.0        22.0     0.0
# 4047      HK-2920   419     9.0         2.0     0.0
#
#                                                 Summary              Role
# 2652  Flew into Colcanin Mountain in heavy fog while...  Utility aircraft
# 2653  While on approach to the airport, in dense fog...  Utility aircraft
# 2654  The plane flew into wake turbulence and crashe...  Utility aircraft
# 2655  Crashed into Long Island Sound while on a flig...  Utility aircraft
# 2656    Crashed after taking off from a dirt air strip.  Utility aircraft
# 2657  Crashed after taking off this North sea island...  Utility aircraft
# 2658  Crashed in rain and fog on the island of Hinno...  Utility aircraft
# 2659                  Crashed on approach into the sea.  Utility aircraft
# 2660                            Crashed while en route.  Utility aircraft
